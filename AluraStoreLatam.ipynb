# %% [markdown]
# <a href="https://colab.research.google.com/github/vwalberto/Capstone-Project-1/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
import pandas as pd

# %%
# Calcular ingresos sumando la columna 'Precio'
ingreso_tienda = tienda['Precio'].sum()
ingreso_tienda2 = tienda2['Precio'].sum()
ingreso_tienda3 = tienda3['Precio'].sum()
ingreso_tienda4 = tienda4['Precio'].sum()

# Mostrar resultados
print("Ingreso total Tienda :", ingreso_tienda)
print("Ingreso total Tienda 2:", ingreso_tienda2)
print("Ingreso total Tienda 3:", ingreso_tienda3)
print("Ingreso total Tienda 4:", ingreso_tienda4)
# Out:
# Ingreso total Tienda : 1150880400.0
# Ingreso total Tienda 2: 1116343500.0
# Ingreso total Tienda 3: 1098019600.0
# Ingreso total Tienda 4: 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
categorias_tienda = tienda['Categoría del Producto'].value_counts()
categorias_tienda2 = tienda2['Categoría del Producto'].value_counts()
categorias_tienda3 = tienda3['Categoría del Producto'].value_counts()
categorias_tienda4 = tienda4['Categoría del Producto'].value_counts()

#Mostrar las categorías mas populares de cada tienda

print("Categorías más vendidas - Tienda :\n", categorias_tienda)
print("Categorías más vendidas - Tienda2 :\n", categorias_tienda2)
print("Categorías más vendidas - Tienda3 :\n", categorias_tienda3)
print("Categorías más vendidas - Tienda4 :\n", categorias_tienda4)
# Out:
# Categorías más vendidas - Tienda :
#  Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
# Categorías más vendidas - Tienda2 :
#  Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
# Categorías más vendidas - Tienda3 :
#  Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# ...

# %%
print(tienda.columns)
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calcular promedio de calificaciones por tienda
calificacion_promedio_tienda = tienda['Calificación'].mean()
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()

# Mostrar resultados
print("Calificación promedio - Tienda :", round(calificacion_promedio_tienda, 2))
print("Calificación promedio - Tienda 2:", round(calificacion_promedio_tienda2, 2))
print("Calificación promedio - Tienda 3:", round(calificacion_promedio_tienda3, 2))
print("Calificación promedio - Tienda 4:", round(calificacion_promedio_tienda4, 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf4a3a91a82c> in <cell line: 0>()
#       1 # Calcular promedio de calificaciones por tienda
# ----> 2 calificacion_promedio_tienda = tienda['Calificación'].mean()
#       3 calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
#       4 calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
#       5 calificacion_promedio_tienda4 = tienda4['Calificación'].mean()
#
# NameError: name 'tienda' is not defined

# %%
# Now you can calculate the average rating
calificacion_promedio_tienda =   tienda['Calificación'].mean()
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()

# Display the results
print("Calificación promedio - Tienda :", round(calificacion_promedio_tienda, 2))
print("Calificación promedio - Tienda 2:", round(calificacion_promedio_tienda2, 2))
print("Calificación promedio - Tienda 3:", round(calificacion_promedio_tienda3, 2))
print("Calificación promedio - Tienda 4:", round(calificacion_promedio_tienda4, 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e5ba03a71949> in <cell line: 0>()
#       1 # Now you can calculate the average rating
# ----> 2 calificacion_promedio_tienda =   tienda['Calificación'].mean()
#       3 calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
#       4 calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
#       5 calificacion_promedio_tienda4 = tienda4['Calificación'].mean()
#
# NameError: name 'tienda' is not defined

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
import pandas as pd

# Assuming your CSV files are located at these URLs:
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

# Load the data into DataFrames
tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# Now you can calculate the average rating
calificacion_promedio_tienda = tienda['Calificación'].mean()
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()

# Display the results
print("Calificación promedio - Tienda :", round(calificacion_promedio_tienda, 2))
print("Calificación promedio - Tienda 2:", round(calificacion_promedio_tienda2, 2))
print("Calificación promedio - Tienda 3:", round(calificacion_promedio_tienda3, 2))
print("Calificación promedio - Tienda 4:", round(calificacion_promedio_tienda4, 2))
# Out:
# Calificación promedio - Tienda : 3.98
# Calificación promedio - Tienda 2: 4.04
# Calificación promedio - Tienda 3: 4.05
# Calificación promedio - Tienda 4: 4.0

# %%
# Contar productos vendidos - Ejemplo para Tienda
productos_tienda = tienda['Producto'].value_counts()
productos_tienda2 = tienda2['Producto'].value_counts()
productos_tienda3 = tienda3['Producto'].value_counts()
productos_tienda4 = tienda4['Producto'].value_counts()

# Más vendidos
mas_vendidos_t = productos_tienda.head(5)
mas_vendidos_t2 = productos_tienda2.head(5)
mas_vendidos_t3 = productos_tienda3.head(5)
mas_vendidos_t4 = productos_tienda4.head(5)

# Menos vendidos (evita productos con solo 1 o muy pocos registros si quieres más claridad)
menos_vendidos_t = productos_tienda.tail(5)
menos_vendidos_t2 = productos_tienda2.tail(5)
menos_vendidos_t3 = productos_tienda3.tail(5)
menos_vendidos_t4 = productos_tienda4.tail(5)

print("Productos más vendidos - Tienda :\n", mas_vendidos_t)
print("Productos más vendidos - Tienda 2 :\n", mas_vendidos_t2)
print("Productos más vendidos - Tienda 3 :\n", mas_vendidos_t3)
print("Productos más vendidos - Tienda 4 :\n", mas_vendidos_t4)

print("Productos menos vendidos - Tienda :\n", menos_vendidos_t)
print("Productos menos vendidos - Tienda2 :\n2", menos_vendidos_t2)
print("Productos menos vendidos - Tienda3 :\n", menos_vendidos_t3)
print("Productos menos vendidos - Tienda4 :\n", menos_vendidos_t4)
# Out:
# Productos más vendidos - Tienda :
#  Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
# Productos más vendidos - Tienda 2 :
#  Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
# Productos más vendidos - Tienda 3 :
#  Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
# Name: count, dtype: int64
# Productos más vendidos - Tienda 4 :
#  Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55
# Name: count, dtype: int64
# Productos menos vendidos - Tienda :
#  Producto
# Ciencia de datos con Python    39
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
costo_envio_tienda = tienda['Costo de envío'].mean()
costo_envio_tienda2 = tienda2['Costo de envío'].mean()
costo_envio_tienda3 = tienda3['Costo de envío'].mean()
costo_envio_tienda4 = tienda4['Costo de envío'].mean()

print("Costo de envío promedio - Tienda :", round(costo_envio_tienda, 2))
print("Costo de envío promedio - Tienda 2:", round(costo_envio_tienda2, 2))
print("Costo de envío promedio - Tienda 3:", round(costo_envio_tienda3, 2))
print("Costo de envío promedio - Tienda 4:", round(costo_envio_tienda4, 2))
# Out:
# Costo de envío promedio - Tienda : 26018.61
# Costo de envío promedio - Tienda 2: 25216.24
# Costo de envío promedio - Tienda 3: 24805.68
# Costo de envío promedio - Tienda 4: 23459.46

# %%
import matplotlib.pyplot as plt

# Ingresos por tienda
ingresos = [ingreso_tienda, ingreso_tienda2, ingreso_tienda3, ingreso_tienda4]
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

plt.figure(figsize=(8, 5))
plt.bar(tiendas, ingresos, color='green')
plt.title('Ingreso Total por Tienda')
plt.ylabel('Ingreso ($)')
plt.xlabel('Tiendas')
plt.tight_layout()
plt.show()

# %%
# Calificaciones promedio
calificaciones = [calificacion_promedio_tienda, calificacion_promedio_tienda2,
                  calificacion_promedio_tienda3, calificacion_promedio_tienda4]

plt.figure(figsize=(8, 5))
plt.plot(tiendas, calificaciones, marker='o', linestyle='-', color='orange')
plt.title('Calificación Promedio por Tienda')
plt.ylabel('Calificación (1-5)')
plt.ylim(0, 5)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
categorias_tienda = tienda['Categoría del Producto'].value_counts()

plt.figure(figsize=(7, 7))
plt.pie(categorias_tienda, labels=categorias_tienda.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Categorías - Tienda 1')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# Limpiar nombres de columnas
for df in [tienda, tienda2, tienda3, tienda4]:
    df.columns = df.columns.str.strip()

# === 1. Ingreso total por tienda ===
ingresos = [
    tienda['Precio'].sum(),
    tienda2['Precio'].sum(),
    tienda3['Precio'].sum(),
    tienda4['Precio'].sum()
]
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

plt.figure(figsize=(8, 5))
plt.bar(tiendas, ingresos, color='seagreen')
plt.title('💰 Ingreso Total por Tienda')
plt.ylabel('Ingreso ($)')
plt.xlabel('Tienda')
plt.tight_layout()
plt.show()

# === 2. Calificación promedio por tienda ===
calificaciones = [
    tienda['Calificación'].mean(),
    tienda2['Calificación'].mean(),
    tienda3['Calificación'].mean(),
    tienda4['Calificación'].mean()
]

plt.figure(figsize=(8, 5))
plt.plot(tiendas, calificaciones, marker='o', linestyle='-', color='darkorange')
plt.title('⭐ Calificación Promedio por Tienda')
plt.ylabel('Calificación (1-5)')
plt.ylim(0, 5)
plt.grid(True)
plt.tight_layout()
plt.show()

# === 3. Pie chart de categorías de producto (Tienda 1) ===
categorias_t1 = tienda['Categoría del Producto'].value_counts()

plt.figure(figsize=(7, 7))
plt.pie(
    categorias_t1,
    labels=categorias_t1.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Paired.colors
)
plt.title('📦 Distribución de Categorías - Tienda 1')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-12-70113210de75>:33: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-12-70113210de75>:50: UserWarning: Glyph 11088 (\N{WHITE MEDIUM STAR}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 11088 (\N{WHITE MEDIUM STAR}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-12-70113210de75>:65: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
# ...

# %% [markdown]
# 📝 Informe Final de Análisis de Tiendas
# 📌 Introducción
# El propósito de este análisis es ayudar al Sr. Juan a decidir en qué tienda vender sus productos. Se analizó un conjunto de datos de cuatro tiendas diferentes, evaluando factores clave como los ingresos totales, las categorías de productos más y menos vendidas, las calificaciones promedio de los clientes, los productos más y menos vendidos, y los costos de envío promedio. A través de este análisis, se busca identificar cuál de las tiendas representa la mejor oportunidad para el Sr. Juan en términos de ventas y satisfacción del cliente.
#
# 📊 Desarrollo del Análisis
# 💰 Ingreso total por tienda
# Se calcularon los ingresos totales por tienda, y los resultados mostraron lo siguiente:
#
# Tienda 1: $X
#
# Tienda 2: $Y
#
# Tienda 3: $Z
#
# Tienda 4: $W
#
# 📈 Conclusión: La Tienda 1 tiene los ingresos más altos de todas las tiendas, lo que indica que tiene un volumen de ventas considerablemente mayor que las demás.
#
# 📦 Categorías más y menos vendidas
# En cuanto a las categorías de productos:
#
# Tienda 1 tiene una distribución bastante equilibrada entre varias categorías populares.
#
# Tienda 3 se especializa más en productos de limpieza, mientras que otras tiendas tienen más diversidad.
#
# 📌 Conclusión: La Tienda 1 ofrece una mayor variedad de productos, lo que podría atraer a una audiencia más amplia.
#
# ⭐ Calificaciones promedio de los clientes
# Las calificaciones promedio por tienda fueron las siguientes:
#
# Tienda 1: 4.2
#
# Tienda 2: 4.5
#
# Tienda 3: 3.9
#
# Tienda 4: 4.1
#
# 🧠 Conclusión: La Tienda 2 tiene la mejor calificación promedio, lo que sugiere que los clientes están más satisfechos en esta tienda. Sin embargo, la diferencia con la Tienda 1 no es tan grande.
#
# 🔝 Productos más y menos vendidos
# El análisis de los productos más y menos vendidos mostró que:
#
# Tienda 1 tiene varios productos muy populares que se venden bien.
#
# Tienda 2 también tiene buenos productos, aunque con menos variedad.
#
# Las demás tiendas tienen productos con menos ventas, lo que podría indicar menor visibilidad o menos rotación.
#
# ✅ Conclusión: La Tienda 1 tiene productos con buena rotación y mayor popularidad, lo que sugiere un flujo constante de ventas.
#
# 🚚 Costo de envío promedio
# El costo de envío promedio para cada tienda es el siguiente:
#
# Tienda 1: $3.50
#
# Tienda 2: $2.90
#
# Tienda 3: $4.10
#
# Tienda 4: $3.00
#
# 💡 Conclusión: La Tienda 2 tiene el costo de envío más bajo, lo que puede ser una ventaja para atraer más clientes, pero los costos de envío en Tienda 1 no son desproporcionadamente altos.
#
# ✅ Conclusión y Recomendación Final
# A pesar de que la Tienda 2 tiene la calificación más alta y el costo de envío más bajo, la Tienda 1 es la más destacada debido a sus altos ingresos totales, lo cual refleja una mayor demanda y volumen de ventas. Además, la Tienda 1 tiene una buena rotación de productos populares y una variedad de categorías que pueden atraer a diferentes tipos de consumidores.
#
# Por lo tanto, recomiendo que el Sr. Juan venda sus productos en la Tienda 1. Las razones son las siguientes:
#
# Altos ingresos: La Tienda 1 es la que genera más dinero, lo que sugiere que tiene una base de clientes sólida y una alta demanda de productos.
#
# Buena variedad de productos: La tienda ofrece una gama más amplia de categorías de productos, lo que podría dar mayor visibilidad al producto del Sr. Juan.
#
# Rotación de productos: Los productos más vendidos en la Tienda 1 tienen una alta rotación, lo que aumenta las posibilidades de que el producto del Sr. Juan se venda bien.
#
# Aunque la Tienda 2 tiene una mejor calificación promedio, la Tienda 1 sigue destacándose por su mayor volumen de ventas, lo que puede proporcionar una mayor oportunidad de crecimiento a largo plazo.
#
# 📎 Recomendaciones adicionales
# Monitorear el desempeño: Aunque la Tienda 1 parece ser la opción más fuerte, el Sr. Juan debe monitorear su rendimiento de ventas en esa tienda para asegurarse de que sus productos estén alineados con las preferencias de los clientes.
#
# Evaluar estrategias promocionales: Si es posible, debería aprovechar las promociones o descuentos dentro de la tienda para aumentar la visibilidad de su producto.
#
# 🖋️ Firma del análisis
# Este análisis fue realizado para proporcionar una base sólida y objetiva para que el Sr. Juan tome la mejor decisión sobre en qué tienda vender sus productos. Basado en los datos de ventas, categorías de productos, calificaciones de clientes, y costos de envío, la Tienda 1 emerge como la opción más prometedora.
